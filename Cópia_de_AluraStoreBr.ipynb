# %% [markdown]
# <a href="https://colab.research.google.com/github/Leandropignataro/analise-gerencial-das-lojas/blob/main/C%C3%B3pia_de_AluraStoreBr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importação dos dados

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_1.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science/refs/heads/main/base-de-dados-challenge-1/loja_4.csv"

loja = pd.read_csv(url)
loja2 = pd.read_csv(url2)
loja3 = pd.read_csv(url3)
loja4 = pd.read_csv(url4)

loja.head()
# Out:
#                  Produto Categoria do Produto    Preço      Frete  \
# 0     Assistente virtual          eletronicos   219.08   9.249790
# 1         Mesa de jantar               moveis   256.35  11.234305
# 2      Jogo de tabuleiro           brinquedos   279.51  21.262681
# 3            Micro-ondas     eletrodomesticos  1009.99  54.667344
# 4  Cadeira de escritório               moveis   446.99  26.964689
#
#   Data da Compra        Vendedor Local da compra  Avaliação da compra  \
# 0     16/01/2021     Pedro Gomes              SP                    4
# 1     18/05/2022  Beatriz Moraes              RJ                    1
# 2     15/03/2021      João Souza              DF                    1
# 3     03/05/2022      João Souza              RS                    4
# 4     07/11/2020   Larissa Alves              MG                    5
#
#   Tipo de pagamento  Quantidade de parcelas    lat    lon
# 0    cartao_credito                       8 -22.19 -48.79
# ...

# %% [markdown]
# #1. Análise do faturamento

# %%
# prompt:  Análise do faturamento de cada loja

# Calcular o faturamento de cada loja
faturamento_loja1 = loja['Preço'].sum()
faturamento_loja2 = loja2['Preço'].sum()
faturamento_loja3 = loja3['Preço'].sum()
faturamento_loja4 = loja4['Preço'].sum()

print(f"Faturamento Loja 1: R${faturamento_loja1:,.2f}")
print(f"Faturamento Loja 2: R${faturamento_loja2:,.2f}")
print(f"Faturamento Loja 3: R${faturamento_loja3:,.2f}")
print(f"Faturamento Loja 4: R${faturamento_loja4:,.2f}")
# Out:
# Faturamento Loja 1: R$1,534,509.12
# Faturamento Loja 2: R$1,488,459.06
# Faturamento Loja 3: R$1,464,025.03
# Faturamento Loja 4: R$1,384,497.58

# %% [markdown]
# # 2. Vendas por Categoria

# %%
# prompt: calcular a quantidade de produtos vendidos por categoria em cada loja. A ideia é agrupar os dados por categoria e contar o número de vendas de cada tipo, mostrando as categoria mais populares de cada loja

# Agrupar por categoria e contar as vendas em cada loja
vendas_por_categoria_loja1 = loja.groupby(loja.columns[1].strip())['Produto'].count().sort_values(ascending=False)
vendas_por_categoria_loja2 = loja2.groupby(loja2.columns[1].strip())['Produto'].count().sort_values(ascending=False)
vendas_por_categoria_loja3 = loja3.groupby(loja3.columns[1].strip())['Produto'].count().sort_values(ascending=False)
vendas_por_categoria_loja4 = loja4.groupby(loja4.columns[1].strip())['Produto'].count().sort_values(ascending=False)

# Exibir as categorias mais populares de cada loja
print("Vendas por categoria - Loja 1:\n", vendas_por_categoria_loja1)
print("\nVendas por categoria - Loja 2:\n", vendas_por_categoria_loja2)
print("\nVendas por categoria - Loja 3:\n", vendas_por_categoria_loja3)
print("\nVendas por categoria - Loja 4:\n", vendas_por_categoria_loja4)
# Out:
# Vendas por categoria - Loja 1:
#  Categoria do Produto
# moveis                   465
# eletronicos              448
# brinquedos               324
# eletrodomesticos         312
# esporte e lazer          284
# instrumentos musicais    182
# livros                   173
# utilidades domesticas    171
# Name: Produto, dtype: int64
#
# Vendas por categoria - Loja 2:
#  Categoria do Produto
# moveis                   442
# eletronicos              422
# brinquedos               313
# eletrodomesticos         305
# esporte e lazer          275
# instrumentos musicais    224
# livros                   197
# utilidades domesticas    181
# Name: Produto, dtype: int64
#
# Vendas por categoria - Loja 3:
#  Categoria do Produto
# moveis                   499
# eletronicos              451
# brinquedos               315
# eletrodomesticos         278
# esporte e lazer          277
# livros                   185
# instrumentos musicais    177
# utilidades domesticas    177
# ...

# %% [markdown]
# # 3. Média de Avaliação das Lojas

# %%
# prompt:  média das avaliações dos clientes para cada loja. O objetivo é entender a satisfação dos clientes com os produtos vendidos.

# Calcular a média das avaliações de cada loja
media_avaliacoes_loja1 = loja['Avaliação da compra'].mean()
media_avaliacoes_loja2 = loja2['Avaliação da compra'].mean()
media_avaliacoes_loja3 = loja3['Avaliação da compra'].mean()
media_avaliacoes_loja4 = loja4['Avaliação da compra'].mean()

print(f"\nMédia de avaliações Loja 1: {media_avaliacoes_loja1:.2f}")
print(f"nMédia de avaliações Loja 2: {media_avaliacoes_loja2:.2f}")
print(f"Média de avaliações Loja 3: {media_avaliacoes_loja3:.2f}")
print(f"Média de avaliações Loja 4: {media_avaliacoes_loja4:.2f}")
# Out:
# Média de avaliações Loja 1: 3.98
# nMédia de avaliações Loja 2: 4.04
# Média de avaliações Loja 3: 4.05
# Média de avaliações Loja 4: 4.00

# %% [markdown]
# # 4. Produtos Mais e Menos Vendidos

# %%
# prompt: identificar quais produtos foram os mais vendidos e os menos vendidos em cada loja.
# Ao final, visualize os resultados de forma que fique claro quais produtos se destacaram nas vendas de cada loja.

# Criar uma função para analisar os produtos mais e menos vendidos
def analisar_produtos(df, loja_num):
    vendas_por_produto = df.groupby('Produto')['Produto'].count().sort_values(ascending=False)
    mais_vendido = vendas_por_produto.index[0]
    menos_vendido = vendas_por_produto.index[-1]
    qtd_mais_vendido = vendas_por_produto.iloc[0]
    qtd_menos_vendido = vendas_por_produto.iloc[-1]
    return mais_vendido, menos_vendido, qtd_mais_vendido, qtd_menos_vendido

# Analisar cada loja
mais_vendido1, menos_vendido1, qtd_mais1, qtd_menos1 = analisar_produtos(loja, 1)
mais_vendido2, menos_vendido2, qtd_mais2, qtd_menos2 = analisar_produtos(loja2, 2)
mais_vendido3, menos_vendido3, qtd_mais3, qtd_menos3 = analisar_produtos(loja3, 3)
mais_vendido4, menos_vendido4, qtd_mais4, qtd_menos4 = analisar_produtos(loja4, 4)

# Imprimir os resultados de forma organizada
print("\nProdutos Mais e Menos Vendidos por Loja:")
print(f"Loja 1: Mais vendido - {mais_vendido1} ({qtd_mais1} unidades), Menos vendido - {menos_vendido1} ({qtd_menos1} unidades)")
print(f"Loja 2: Mais vendido - {mais_vendido2} ({qtd_mais2} unidades), Menos vendido - {menos_vendido2} ({qtd_menos2} unidades)")
print(f"Loja 3: Mais vendido - {mais_vendido3} ({qtd_mais3} unidades), Menos vendido - {menos_vendido3} ({qtd_menos3} unidades)")
print(f"Loja 4: Mais vendido - {mais_vendido4} ({qtd_mais4} unidades), Menos vendido - {menos_vendido4} ({qtd_menos4} unidades)")
# Out:
# Produtos Mais e Menos Vendidos por Loja:
# Loja 1: Mais vendido - TV Led UHD 4K (60 unidades), Menos vendido - Headset (33 unidades)
# Loja 2: Mais vendido - Iniciando em programação (65 unidades), Menos vendido - Jogo de tabuleiro (32 unidades)
# Loja 3: Mais vendido - Kit banquetas (57 unidades), Menos vendido - Blocos de montar (35 unidades)
# Loja 4: Mais vendido - Cama box (62 unidades), Menos vendido - Guitarra (33 unidades)

# %% [markdown]
# # 5. Frete Médio por Loja

# %%
# prompt: calcular o custo médio de frete para cada loja.
# O objetivo é entender quanto, em média, está sendo gasto com frete para cada uma das lojas

# Calcular o frete médio de cada loja
frete_medio_loja1 = loja['Frete'].mean()
frete_medio_loja2 = loja2['Frete'].mean()
frete_medio_loja3 = loja3['Frete'].mean()
frete_medio_loja4 = loja4['Frete'].mean()

print("\nFrete Médio por Loja:")
print(f"Loja 1: R${frete_medio_loja1:,.2f}")
print(f"Loja 2: R${frete_medio_loja2:,.2f}")
print(f"Loja 3: R${frete_medio_loja3:,.2f}")
print(f"Loja 4: R${frete_medio_loja4:,.2f}")
# Out:
# Frete Médio por Loja:
# Loja 1: R$34.69
# Loja 2: R$33.62
# Loja 3: R$33.07
# Loja 4: R$31.28

# %% [markdown]
# ### GRAFICOS: FATURAMENTO, VENDAS POR PRODUTO

# %%
# prompt: GRAFICO faturamento das lojas

import matplotlib.pyplot as plt

# Dados de faturamento (substitua pelos seus dados reais)
lojas = ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4']
faturamentos = [faturamento_loja1, faturamento_loja2, faturamento_loja3, faturamento_loja4]

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))  # Ajustar o tamanho da figura
plt.bar(lojas, faturamentos, color=['skyblue', 'lightcoral', 'lightgreen', 'gold'])
plt.xlabel('Lojas')
plt.ylabel('Faturamento (R$)')
plt.title('Faturamento por Loja')
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adicionar rótulos de valor acima de cada barra
for i, v in enumerate(faturamentos):
    plt.text(i, v + 100, f'R${v:,.2f}', ha='center', va='bottom')


plt.show()

# %%
# prompt: GRAFICO de pizza quantidade de produtos vendidos por categoria em cada loja

# Create subplots for each store
fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Function to create pie chart for each store
def plot_pie_chart(ax, data, title):
    ax.pie(data.values, labels=data.index, autopct='%1.1f%%', startangle=90)
    ax.axis('equal')
    ax.set_title(title)

# Plot pie charts for each store
plot_pie_chart(axes[0, 0], vendas_por_categoria_loja1, 'Loja 1')
plot_pie_chart(axes[0, 1], vendas_por_categoria_loja2, 'Loja 2')
plot_pie_chart(axes[1, 0], vendas_por_categoria_loja3, 'Loja 3')
plot_pie_chart(axes[1, 1], vendas_por_categoria_loja4, 'Loja 4')


plt.tight_layout() # Adjust layout to prevent overlapping
plt.show()

# %%
# prompt: grafico de linha coluna aonde a linha e custo frete e a coluna a Média de Avaliação das Lojas

# Create a DataFrame with the average rating and shipping cost for each store
data = {'Loja': ['Loja 1', 'Loja 2', 'Loja 3', 'Loja 4'],
        'Média de Avaliação': [media_avaliacoes_loja1, media_avaliacoes_loja2, media_avaliacoes_loja3, media_avaliacoes_loja4],
        'Custo de Frete': [frete_medio_loja1, frete_medio_loja2, frete_medio_loja3, frete_medio_loja4]}
df = pd.DataFrame(data)

# Create the combined chart
plt.figure(figsize=(10, 6))
plt.bar(df['Loja'], df['Média de Avaliação'], label='Média de Avaliação')
plt.plot(df['Loja'], df['Custo de Frete'], marker='o', color='red', label='Custo de Frete')

# Customize the chart
plt.xlabel('Lojas')
plt.ylabel('Valores')
plt.title('Média de Avaliação vs. Custo de Frete por Loja')
plt.legend()
plt.grid(True)

plt.show()

# %%
# prompt: Utilize os dados de latitude (lat) e longitude (lon) para mapear as vendas das lojas e analisar a distribuição geográfica dos produtos vendidos.
# Gere gráficos de dispersão para visualizar os dados e identificar áreas com maior concentração de vendas.

# Import necessary libraries if not already imported
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your dataframe is named 'loja' (or similar for other stores)
# and it contains 'lat' and 'lon' columns representing latitude and longitude

# Function to create scatter plot for sales distribution
def plot_sales_distribution(df, title):
    plt.figure(figsize=(10, 6))
    plt.scatter(df['lon'], df['lat'], s=df['Preço'], c=df['Preço'], cmap='viridis')  # Use 'Preço' for size and color
    plt.xlabel("Longitude")
    plt.ylabel("Latitude")
    plt.title(title)
    plt.colorbar(label='Preço') # Add a colorbar to show the price scale
    plt.show()


# Example usage (replace with your dataframe)
plot_sales_distribution(loja, 'Distribuição geográfica das vendas da Loja 1')
plot_sales_distribution(loja2, 'Distribuição geográfica das vendas da Loja 2')
plot_sales_distribution(loja3, 'Distribuição geográfica das vendas da Loja 3')
plot_sales_distribution(loja4, 'Distribuição geográfica das vendas da Loja 4')

# %% [markdown]
# ## **RELATORIO FINAL**
#
# > **Fatores analisados para uma possivel venda de uma loja**:
#
# *  *O faturamento total das lojas*.
# *  *As categorias de produtos mais e menos vendidas*.
# *  *A média das avaliações de clientes por loja*.
# *  *Os produtos mais e menos vendidos*.
# *  *O frete médio de cada loja*.
#
#
# No relatório, apoiada nas análises e nas visualizações / graficos.
#  Identificamos que:
#   1. as lojas tem muita similaridades nas vendas dos produtos (ver grafico
# pizza).
#
# 2. os custos de frete (ver frete medio) , sao proporcionais ao faturamento (ver grafico faturamento). O que indica, que os custos operacionais sao equivalentes.
#
# 3. Logo, observa-se que as lojas nao se destacam em relação às outras, nem pelos custos ou pontuacao , ao nao ser pelas vendas / faturamento.
#
# ----
#
#   **CONCLUSAO**
#
#
# > As lojas do Senhor João que deve vender, levando em consideração todos os fatores, eh a de _menor faturamento_;
#
# > **Mas nao eh relevante ou ponto critico esse fator, para a venda**, visto que tem uma boa notas com os clientes;
#
# > **Logo**, a sugestao eh avaliar qual loja tem o maior/melhor preco no mercado , e buscar **maximizar o ganho de capital**
